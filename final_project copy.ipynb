# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.4.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp313-cp313-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 78.4 MB/s  0:00:00
# Using cached numpy-2.4.4-cp313-cp313-macosx_14_0_arm64.whl (5.2 MB)
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.4 pandas-3.0.2
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd
import openpyxl


df = pd.read_excel("data/smileystatus.xlsx")

df.head()
# Out:
#    navnelbnr       cvrnr           pnr  brancheKode  \
# 0     513605  34583730.0  1.017699e+09  DD.10.71.20
# 1      26029  18043041.0  1.001418e+09  DD.10.71.20
# 2      69750  21467782.0  1.004954e+09  DD.10.71.20
# 3     555571  18623978.0  1.019633e+09  DD.10.71.20
# 4    1292639  43771930.0  1.028920e+09  DD.10.71.20
#
#                           branche virksomhedstype  \
# 0  Specialforretning - Bager m.v.          Detail
# 1  Specialforretning - Bager m.v.          Detail
# 2  Specialforretning - Bager m.v.          Detail
# 3  Specialforretning - Bager m.v.          Detail
# 4  Specialforretning - Bager m.v.          Detail
#
#                          navn1            adresse1  postnr            By  ...  \
# 0                  Firdaws ApS      Enghavevej 172    2450  København SV  ...
# 1                KonditorBager  Dannebrogsgade  21    9700   Brønderslev  ...
# 2           NYTORVS BAGERI APS           Nytorv  1    7323          Give  ...
# 3  SuperBrugsen Havdrup Bageri      Møllemarken  6    4622       Havdrup  ...
# 4                  Digebageren  Storegade 20 stuen    6280         Højer  ...
#
#    naestseneste_kontrol_dato tredjeseneste_kontrol  \
# 0                 2024-02-07                   1.0
# 1                 2021-12-09                   2.0
# 2                 2024-04-22                   1.0
# 3                 2024-12-17                   1.0
# 4                 2024-11-27                   1.0
#
#    tredjeseneste_kontrol_dato fjerdeseneste_kontrol  \
# 0                  2023-11-27                   1.0
# 1                  2021-10-20                   1.0
# 2                  2023-10-06                   1.0
# 3                  2024-09-18                   1.0
# 4                  2024-04-10                   1.0
#
#    fjerdeseneste_kontrol_dato  \
# 0                  2023-11-15
# 1                  2019-09-24
# 2                  2023-06-14
# 3                  2024-04-04
# 4                  2023-12-20
#
#                                                  URL  reklame_beskyttelse  \
# 0  http://www.findsmiley.dk/da-DK/Searching/Detai...                    0
# 1  http://www.findsmiley.dk/da-DK/Searching/Detai...                    0
# 2  http://www.findsmiley.dk/da-DK/Searching/Detai...                    0
# 3  http://www.findsmiley.dk/da-DK/Searching/Detai...                    0
# 4  http://www.findsmiley.dk/da-DK/Searching/Detai...                    0
#
#   Elite_Smiley    Geo_Lng    Geo_Lat
# 0            0  12.537889  55.656613
# 1            0   9.950767  57.270705
# 2            0   9.237281  55.844766
# 3            0  12.115530  55.543675
# 4            0        NaN        NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # 1 - Motivation
# - what is your dataset?
# - Why did you choose this data?
# - What was your goal for the end users experience?

# %% [markdown]
# # 2 - Basic Stats
# - Write about choices in datacleaning and preprocessing
# - Write a short section discussin datasets stats containing key points/plot from exploratory data analysis

# %% [markdown]
# # 3 - Data Analysis
# - Describe analysis and explain what you have learned
# - Talk about machine learning if relevant

# %% [markdown]
# # 4 - Genre
# - Which tools did you use for visual narrative and why?
# - Which ... for narrative structure and why?

# %% [markdown]
# # 5 - Visualizations
# - Explain the visualizations chosen
# - Why are they right for the story we want to tell

# %% [markdown]
# # 6 - Discussion
# - what went well
# - what is missing and could be improved
# - and why

# %% [markdown]
# # 7 - Contributions
# - NOT okay that all contributed equally..

# %%
import pandas as pd

df2 = df.rename(columns={
    "seneste_kontrol": "kontrol_1",
    "seneste_kontrol_dato": "dato_1",
    "naestseneste_kontrol": "kontrol_2",
    "naestseneste_kontrol_dato": "dato_2",
    "tredjeseneste_kontrol": "kontrol_3",
    "tredjeseneste_kontrol_dato": "dato_3",
    "fjerdeseneste_kontrol": "kontrol_4",
    "fjerdeseneste_kontrol_dato": "dato_4"
})

df_long = (
    pd.wide_to_long(
        df2,
        stubnames=["kontrol", "dato"],
        i="navnelbnr",
        j="tjek_nr",
        sep="_"
    )
    .reset_index()
)

df_long = df_long.dropna(subset=["kontrol", "dato"])
df_long["dato"] = pd.to_datetime(df_long["dato"])

# %%
df_long["branche"].value_counts()

#len(df_long["branche"].unique())
# Out:
# branche
# Serveringsvirksomhed - Restauranter m.v.                        64674
# Serveringsvirksomhed - Institutionskøkkener m.v.                30856
# Dagligvareforretning uden/med begrænset behandling              26498
# Serveringsvirksomhed - Uden behandling                           5980
# Lager/lagerhotel og evt. engroshandel - Uden køl/frost           4802
# Specialforretning - Delikatesse, specialiteter m.v. med beha     4536
# Specialforretning - Bager m.v.                                   3820
# Kontorvirksomhed eller agenturvirksomhed - uden lager            3761
# Specialforretning - Slagter m.v.                                 3621
# Transportvirksomhed, engros                                      2595
# Markedsføring af fødevarekontaktmaterialer, engros               2580
# Fremstilling af fødevarekontaktmaterialer, engros                2454
# Fremstilling af vegetabilske produkter mv. evt. med indhold      1831
# Catering med levering til detailvirksomheder (detail med eng     1495
# Lager/lagerhotel og evt. engroshandel - Med køl/frost            1480
# Specialforretning - Fisk m.v.                                    1140
# Fremstilling af drikkevarer m.v.                                  914
# Fremstilling af animalske produkter - Fisk og muslinger m.v.      800
# Lager og evt. engroshandel med salg til detailvirksomheder (      706
# Fremstilling af animalske produkter - Kød                         540
# Fremstilling af animalske produkter - Mælk og ost                 386
# Fremstilling af kosttilskud, tilsætningsstoffer m.v.              385
# Markedsføring af fødevarekontaktmaterialer, detail                329
# Slagterier                                                        314
# Fremstilling af fødevarekontaktmaterialer, detail                 306
# Virksomhed, foreløbig: Detailforr. m. beh., fx mikrobryggeri      194
# Frysehuse med indfrysning af animalske produkter                  113
# Kædekontrolhovedkontor - Fødevarer                                 85
# Fremstilling af animalske produkter - Andre produkter              64
# Slagtebusser                                                       62
# Virksomhed, foreløbig: Engroshandel og/eller lager/lagerhote       44
# Transportvirksomhed, detail                                        42
# Virksomhed, foreløbig: Internethandel, udelukkende salg og m       39
# Virksomhed, foreløbig: Butikshandel, fx kiosk, apotek, helse       25
# Virksomhed, foreløbig: Restaurant, pizzeria, cafe, kantine,        23
# Fremstilling af animalske produkter - Æg                           20
# Håndtering af levende toskallede bløddyr                           16
# Kvindemælkscentraler (detail med engros)                           12
# Virksomhed, foreløbig: Fremstill. af fødevarekontaktmaterial        6
# Virksomhed, foreløbig: Institutionskøkken, fx børneinstituti        6
# Virksomhed, foreløbig: Mobil virksomh.(fx salg af br. mandl.        6
# Virksomhed, foreløbig: Butikshandel, fx dagligvareforr., grø        5
# Virksomhed, foreløbig: Fremstill. af bagværk, brød, pasta o.        4
# Virksomhed, foreløbig: Fremstill./pakn. af drikkev., maltfab        4
# Virksomhed, foreløbig: Smørrebrødsforr., delikatesseafd., ta        4
# Virksomhed, foreløbig: Servering, fx værtshus, vinbar, autom        3
# Virksomhed, foreløbig: Slagter, slagterafdeling                     3
# Virksomhed, foreløbig: Kontorvirksomhed (fødevarer og/eller         2
# Virksomhed, foreløbig: Transportvirksomhed, engros                  2
# Virksomhed, foreløbig: Fremstill./pakn. af konfekture, sukke        2
# Virksomhed, foreløbig: Fremstill./pakn. af tils.stoff., kost        1
# Virksomhed, foreløbig AUT: Slagteri, slagteri med fremstilli        1
# Virksomhed, foreløbig AUT: Fremstill./pakn. primært ud fra m        1
# Virksomhed, foreløbig: Bagerforretning, bagerafdeling, kondi        1
# Name: count, dtype: int64

# %%
df_long["By"].value_counts().head(20)
# Out:
# By
# København K      5229
# København V      3631
# København S      3483
# Århus C          3408
# København Ø      2782
# Aalborg          2619
# København N      2538
# Odense C         2261
# Roskilde         2225
# Vejle            2036
# Kolding          2011
# Frederiksberg    1915
# Horsens          1733
# Silkeborg        1663
# Herning          1640
# Hillerød         1523
# Viborg           1518
# Valby            1452
# København NV     1432
# Hvidovre         1412
# Name: count, dtype: int64

# %%
df_long["dato"] = pd.to_datetime(df_long["dato"])

df_long.groupby(df_long["dato"].dt.year)["kontrol"].mean()
df_long.groupby(df_long["dato"].dt.year)["kontrol"].size()
# Out:
# dato
# 2003        1
# 2004       82
# 2005      145
# 2006      231
# 2007      296
# 2008      247
# 2009      334
# 2010      334
# 2011      443
# 2012      387
# 2013      519
# 2014      938
# 2015     1376
# 2016     2680
# 2017     3977
# 2018     6541
# 2019     9200
# 2020     6443
# 2021    10485
# 2022    16200
# 2023    25162
# 2024    31778
# 2025    37404
# 2026    12390
# Name: kontrol, dtype: int64

# %%
df_long.groupby("branche")["kontrol"].mean().sort_values()
# Out:
# branche
# Virksomhed, foreløbig: Slagter, slagterafdeling                 1.000000
# Virksomhed, foreløbig: Mobil virksomh.(fx salg af br. mandl.    1.000000
# Virksomhed, foreløbig: Institutionskøkken, fx børneinstituti    1.000000
# Virksomhed, foreløbig: Fremstill./pakn. af drikkev., maltfab    1.000000
# Virksomhed, foreløbig: Bagerforretning, bagerafdeling, kondi    1.000000
# Virksomhed, foreløbig AUT: Slagteri, slagteri med fremstilli    1.000000
# Virksomhed, foreløbig: Smørrebrødsforr., delikatesseafd., ta    1.000000
# Kvindemælkscentraler (detail med engros)                        1.000000
# Håndtering af levende toskallede bløddyr                        1.000000
# Fremstilling af fødevarekontaktmaterialer, engros               1.023227
# Slagterier                                                      1.038217
# Catering med levering til detailvirksomheder (detail med eng    1.049498
# Lager og evt. engroshandel med salg til detailvirksomheder (    1.056657
# Fremstilling af fødevarekontaktmaterialer, detail               1.065359
# Fremstilling af drikkevarer m.v.                                1.067834
# Kædekontrolhovedkontor - Fødevarer                              1.070588
# Serveringsvirksomhed - Institutionskøkkener m.v.                1.075058
# Transportvirksomhed, engros                                     1.076301
# Fremstilling af animalske produkter - Andre produkter           1.078125
# Specialforretning - Fisk m.v.                                   1.083333
# Specialforretning - Slagter m.v.                                1.084783
# Markedsføring af fødevarekontaktmaterialer, engros              1.086047
# Frysehuse med indfrysning af animalske produkter                1.088496
# Lager/lagerhotel og evt. engroshandel - Uden køl/frost          1.092670
# Specialforretning - Delikatesse, specialiteter m.v. med beha    1.097002
# Fremstilling af animalske produkter - Æg                        1.100000
# Lager/lagerhotel og evt. engroshandel - Med køl/frost           1.100000
# Kontorvirksomhed eller agenturvirksomhed - uden lager           1.100239
# Fremstilling af animalske produkter - Fisk og muslinger m.v.    1.106250
# Fremstilling af kosttilskud, tilsætningsstoffer m.v.            1.109091
# Fremstilling af vegetabilske produkter mv. evt. med indhold     1.111415
# Slagtebusser                                                    1.112903
# Serveringsvirksomhed - Restauranter m.v.                        1.118378
# Transportvirksomhed, detail                                     1.119048
# Dagligvareforretning uden/med begrænset behandling              1.124387
# Fremstilling af animalske produkter - Kød                       1.137037
# Serveringsvirksomhed - Uden behandling                          1.143311
# Fremstilling af animalske produkter - Mælk og ost               1.147668
# Specialforretning - Bager m.v.                                  1.148953
# Markedsføring af fødevarekontaktmaterialer, detail              1.170213
# Virksomhed, foreløbig: Restaurant, pizzeria, cafe, kantine,     1.217391
# Virksomhed, foreløbig: Butikshandel, fx kiosk, apotek, helse    1.280000
# Virksomhed, foreløbig: Transportvirksomhed, engros              1.500000
# Virksomhed, foreløbig: Detailforr. m. beh., fx mikrobryggeri    1.556701
# Virksomhed, foreløbig: Butikshandel, fx dagligvareforr., grø    1.600000
# Virksomhed, foreløbig: Servering, fx værtshus, vinbar, autom    1.666667
# Virksomhed, foreløbig: Fremstill. af fødevarekontaktmaterial    1.833333
# Virksomhed, foreløbig: Internethandel, udelukkende salg og m    1.871795
# Virksomhed, foreløbig: Kontorvirksomhed (fødevarer og/eller     2.000000
# Virksomhed, foreløbig: Engroshandel og/eller lager/lagerhote    2.068182
# Virksomhed, foreløbig: Fremstill./pakn. af konfekture, sukke    2.500000
# Virksomhed, foreløbig: Fremstill. af bagværk, brød, pasta o.    3.500000
# Virksomhed, foreløbig: Fremstill./pakn. af tils.stoff., kost    4.000000
# Virksomhed, foreløbig AUT: Fremstill./pakn. primært ud fra m    4.000000
# Name: kontrol, dtype: float64

# %%
df_long.groupby("By")["kontrol"].mean().sort_values(ascending=False).head(10)
# Out:
# By
# Havndal         1.292683
# Bevtoft         1.285714
# Vandel          1.285714
# Torrig L        1.275862
# Åbyhøj          1.273859
# Gandrup         1.272727
# Bylderup Bov    1.250000
# Tranbjerg J     1.250000
# Tylstrup        1.232558
# Brabrand        1.222764
# Name: kontrol, dtype: float64

# %%
df_long.groupby("kontrol")["branche"].size()
# Out:
# kontrol
# 0.0         2
# 1.0    153464
# 2.0     12016
# 3.0       370
# 4.0      1741
# Name: branche, dtype: int64
