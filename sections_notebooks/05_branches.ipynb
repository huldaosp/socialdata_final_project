# %%
# !pip install plotly
# !pip install nbformat

# %%
import json
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# %%
df = pd.read_csv('../data/processed_smiley.xlsx')
df.info()
